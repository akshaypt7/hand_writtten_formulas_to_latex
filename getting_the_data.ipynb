# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaypt7/hand_writtten_formulas_to_latex/blob/vishal/getting_the_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle

# %% [markdown]
# Before this step, go to "Account" on Kaggle and click "Create new API token". This will download a .json file. Upload that file here

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4f3b9dce-b914-4dfa-a2e4-d33869fe830d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f3b9dce-b914-4dfa-a2e4-d33869fe830d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vishalbalajiv","key":"c748847b5350b9c9cfffab3868e11aa9"}'}

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle datasets download xainano/handwrittenmathsymbols
# Out:
# ...
#  96% 329M/343M [00:12<00:00, 26.6MB/s]
# 100% 343M/343M [00:12<00:00, 28.8MB/s]

# %%
# !unzip /content/handwrittenmathsymbols.zip

# %%
#Unzipping straight to Colab
# !unrar x '/content/data.rar' '/content/drive/MyDrive/Colab-files/AI - 2/Project/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...
